# %%
import os
import yaml
import pandas as pd
from collections import defaultdict

def load_yaml_file(file_path):
    with open(file_path, 'r') as file:
        return yaml.safe_load(file)

def extract_stock_data_without_sector(root_dir):
    symbol_data = defaultdict(list)

    for month_folder in sorted(os.listdir(root_dir)):
        month_path = os.path.join(root_dir, month_folder)

        if not os.path.isdir(month_path):
            continue

        for filename in sorted(os.listdir(month_path)):
            if filename.endswith('.yaml'):
                file_path = os.path.join(month_path, filename)

                try:
                    data_entries = load_yaml_file(file_path)
                except Exception as e:
                    print(f"Error reading {file_path}: {e}")
                    continue

                if not isinstance(data_entries, list):
                    print(f"⚠️ Skipped non-list YAML: {file_path}")
                    continue

                for entry in data_entries:
                    symbol = entry.get('Ticker')  # ✔️ Correct key here
                    if symbol is None:
                        continue

                    record = {
                        'date': entry.get('date'),
                        'symbol': symbol,
                        'open': entry.get('open'),
                        'close': entry.get('close'),
                        'high': entry.get('high'),
                        'low': entry.get('low'),
                        'volume': entry.get('volume'),
                        'month': entry.get('month')  # Already included
                    }
                    symbol_data[symbol].append(record)

    return symbol_data

def save_symbol_csvs(symbol_data, output_dir='output_csvs'):
    os.makedirs(output_dir, exist_ok=True)

    for symbol, records in symbol_data.items():
        df = pd.DataFrame(records)
        df.sort_values(by='date', inplace=True)
        df.to_csv(os.path.join(output_dir, f'{symbol}.csv'), index=False)
        print(f"✅ Saved: {symbol}.csv with {len(df)} records")

def main():
    root_yaml_dir = 'data'  # ⚠️ Change this to your folder containing month folders
    print("🔄 Extracting stock data (without sector)...")
    all_symbol_data = extract_stock_data_without_sector(root_yaml_dir)
    save_symbol_csvs(all_symbol_data)
    print("🎉 Step 1 done: CSVs created.")

if __name__ == '__main__':
    main()
# Out:
# 🔄 Extracting stock data (without sector)...
# ✅ Saved: SBIN.csv with 284 records
# ✅ Saved: BAJFINANCE.csv with 284 records
# ✅ Saved: TITAN.csv with 284 records
# ✅ Saved: ITC.csv with 284 records
# ✅ Saved: TCS.csv with 284 records
# ✅ Saved: LT.csv with 284 records
# ✅ Saved: TATACONSUM.csv with 284 records
# ✅ Saved: RELIANCE.csv with 284 records
# ✅ Saved: HCLTECH.csv with 284 records
# ✅ Saved: JSWSTEEL.csv with 284 records
# ✅ Saved: ULTRACEMCO.csv with 284 records
# ✅ Saved: POWERGRID.csv with 284 records
# ✅ Saved: INFY.csv with 284 records
# ✅ Saved: TRENT.csv with 284 records
# ✅ Saved: BHARTIARTL.csv with 284 records
# ✅ Saved: TATAMOTORS.csv with 284 records
# ✅ Saved: WIPRO.csv with 284 records
# ✅ Saved: TECHM.csv with 284 records
# ✅ Saved: NTPC.csv with 284 records
# ✅ Saved: HINDUNILVR.csv with 284 records
# ✅ Saved: APOLLOHOSP.csv with 284 records
# ✅ Saved: M&M.csv with 284 records
# ✅ Saved: GRASIM.csv with 284 records
# ✅ Saved: ICICIBANK.csv with 284 records
# ✅ Saved: ADANIENT.csv with 284 records
# ✅ Saved: ADANIPORTS.csv with 284 records
# ✅ Saved: BEL.csv with 284 records
# ✅ Saved: BAJAJFINSV.csv with 284 records
# ✅ Saved: EICHERMOT.csv with 284 records
# ✅ Saved: COALINDIA.csv with 284 records
# ✅ Saved: MARUTI.csv with 284 records
# ✅ Saved: INDUSINDBK.csv with 284 records
# ✅ Saved: ASIANPAINT.csv with 284 records
# ✅ Saved: TATASTEEL.csv with 284 records
# ✅ Saved: HDFCLIFE.csv with 284 records
# ✅ Saved: DRREDDY.csv with 284 records
# ✅ Saved: SUNPHARMA.csv with 284 records
# ✅ Saved: KOTAKBANK.csv with 284 records
# ✅ Saved: SHRIRAMFIN.csv with 284 records
# ✅ Saved: NESTLEIND.csv with 284 records
# ✅ Saved: ONGC.csv with 284 records
# ✅ Saved: CIPLA.csv with 284 records
# ✅ Saved: BPCL.csv with 284 records
# ✅ Saved: BRITANNIA.csv with 284 records
# ✅ Saved: SBILIFE.csv with 284 records
# ✅ Saved: HINDALCO.csv with 284 records
# ✅ Saved: HEROMOTOCO.csv with 284 records
# ✅ Saved: AXISBANK.csv with 284 records
# ✅ Saved: HDFCBANK.csv with 284 records
# ✅ Saved: BAJAJ-AUTO.csv with 284 records
# 🎉 Step 1 done: CSVs created.

# %%
def add_sector_to_csvs(csv_dir='output_csvs', sector_mapping=None):
    if sector_mapping is None:
        print("⚠️ No sector mapping provided.")
        return

    for filename in os.listdir(csv_dir):
        if filename.endswith('.csv'):
            symbol = filename.replace('.csv', '')
            filepath = os.path.join(csv_dir, filename)

            try:
                df = pd.read_csv(filepath)
                df['sector'] = sector_mapping.get(symbol, 'Unknown')
                df.to_csv(filepath, index=False)
                print(f"✅ Updated: {filename} with sector")
            except Exception as e:
                print(f"❌ Failed to update {filename}: {e}")

def main():
    # 🧭 Add your actual sector mapping below
    sector_mapping = {
        "RELIANCE": "Energy",
    "TCS": "IT",
    "INFY": "IT",
    "HDFCBANK": "Financials",
    "ICICIBANK": "Financials",
    "SBIN": "Financials",
    "ITC": "FMCG",
    "HINDUNILVR": "FMCG",
    "LT": "Capital Goods",
    "AXISBANK": "Financials",
    "KOTAKBANK": "Financials",
    "WIPRO": "IT",
    "BHARTIARTL": "Telecom",
    "ASIANPAINT": "Consumer Durables",
    "ONGC": "Energy",
    "COALINDIA": "Energy",
    "NTPC": "Utilities",
    "POWERGRID": "Utilities",
    "ADANIENT": "Conglomerate",
    "ADANIPORTS": "Transportation",
    "CIPLA": "Pharma",
    "DRREDDY": "Pharma",
    "TATAMOTORS": "Automobile",
    "TATASTEEL": "Metals",
    "JSWSTEEL": "Metals",
    "ULTRACEMCO": "Cement",
    "BAJFINANCE": "Financials",
    "BAJAJFINSV": "Financials",
    "HCLTECH": "IT",
    "MARUTI": "Automobile",
    "HDFCLIFE": "Insurance",
    "DIVISLAB": "Pharma",
    "EICHERMOT": "Automobile",
    "BAJAJ-AUTO": "Automobile",
    "HEROMOTOCO": "Automobile",
    "HINDALCO": "Metals",
    "GRASIM": "Cement",
    "SBILIFE": "Insurance",
    "TECHM": "IT",
    "BRITANNIA": "FMCG",
    "INDUSINDBK": "Financials",
    "NESTLEIND": "FMCG",
    "TITAN": "Consumer Durables",
    "UPL": "Chemicals",
    "APOLLOHOSP": "Healthcare",
    "TRENT": "Retail",
    "TATACONSUM": "FMCG",
    "SUNPHARMA": "Pharma",
    "SHRIRAMFIN": "Financials",
    "M&M": "Automobile",
    "BPCL": "Energy",
    "BEL": "Defense"
        
    }

    print("🛠️ Adding sector info to CSVs...")
    add_sector_to_csvs(csv_dir='output_csvs', sector_mapping=sector_mapping)
    print("🎉 Step 2 done: Sector column added.")

if __name__ == '__main__':
    main()
# Out:
# 🛠️ Adding sector info to CSVs...
# ✅ Updated: ADANIENT.csv with sector
# ✅ Updated: ADANIPORTS.csv with sector
# ✅ Updated: APOLLOHOSP.csv with sector
# ✅ Updated: ASIANPAINT.csv with sector
# ✅ Updated: AXISBANK.csv with sector
# ✅ Updated: BAJAJ-AUTO.csv with sector
# ✅ Updated: BAJAJFINSV.csv with sector
# ✅ Updated: BAJFINANCE.csv with sector
# ✅ Updated: BEL.csv with sector
# ✅ Updated: BHARTIARTL.csv with sector
# ✅ Updated: BPCL.csv with sector
# ✅ Updated: BRITANNIA.csv with sector
# ✅ Updated: CIPLA.csv with sector
# ✅ Updated: COALINDIA.csv with sector
# ✅ Updated: DRREDDY.csv with sector
# ✅ Updated: EICHERMOT.csv with sector
# ✅ Updated: GRASIM.csv with sector
# ✅ Updated: HCLTECH.csv with sector
# ✅ Updated: HDFCBANK.csv with sector
# ✅ Updated: HDFCLIFE.csv with sector
# ✅ Updated: HEROMOTOCO.csv with sector
# ✅ Updated: HINDALCO.csv with sector
# ✅ Updated: HINDUNILVR.csv with sector
# ✅ Updated: ICICIBANK.csv with sector
# ✅ Updated: INDUSINDBK.csv with sector
# ✅ Updated: INFY.csv with sector
# ✅ Updated: ITC.csv with sector
# ✅ Updated: JSWSTEEL.csv with sector
# ✅ Updated: KOTAKBANK.csv with sector
# ✅ Updated: LT.csv with sector
# ✅ Updated: M&M.csv with sector
# ✅ Updated: MARUTI.csv with sector
# ✅ Updated: NESTLEIND.csv with sector
# ✅ Updated: NTPC.csv with sector
# ✅ Updated: ONGC.csv with sector
# ✅ Updated: POWERGRID.csv with sector
# ✅ Updated: RELIANCE.csv with sector
# ✅ Updated: SBILIFE.csv with sector
# ✅ Updated: SBIN.csv with sector
# ✅ Updated: SHRIRAMFIN.csv with sector
# ✅ Updated: SUNPHARMA.csv with sector
# ✅ Updated: TATACONSUM.csv with sector
# ✅ Updated: TATAMOTORS.csv with sector
# ✅ Updated: TATASTEEL.csv with sector
# ✅ Updated: TCS.csv with sector
# ✅ Updated: TECHM.csv with sector
# ✅ Updated: TITAN.csv with sector
# ✅ Updated: TRENT.csv with sector
# ✅ Updated: ULTRACEMCO.csv with sector
# ✅ Updated: WIPRO.csv with sector
# 🎉 Step 2 done: Sector column added.
